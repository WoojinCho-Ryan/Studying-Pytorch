# %% [markdown]
# <a href="https://colab.research.google.com/github/WoojinCho-Ryan/Studying-Pytorch/blob/main/4_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4-1. Logistic Regression

# %% [markdown]
# 일상 속 풀고자 하는 많은 문제 중에서는 2개의 선택지 중 정답을 고르는 문제가 많음. 이러한 문제를 **Binary Classification** 이라고 하며, 이를 풀기 위한 대표적인 algorithm으로 **Logistic Regression**이 있음.
#
# - Logistic Regression은 algorithm의 이름은 regression이나 실제로는 classification 작업에 사용될 수 있음.
